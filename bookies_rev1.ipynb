# %%
import pandas as pd
import hvplot.pandas
import datetime as dt
import holoviews as hv
import requests
import logging
import betfairlightweight
import os
import sys

# %%
"""
Historic is the API endpoint that can be used to
download data betfair provide.

https://historicdata.betfair.com/#/apidocs
"""

# setup logging
logging.basicConfig(level=logging.INFO)  # change to DEBUG to see log all updates

# %%
# create trading instance
trading = betfairlightweight.APIClient("darcyroydavis@gmail.com", "Za$EYD7y.g25j9L", app_key="js3EWmgRixTXqwUL")

# %%
# login
trading.login_interactive()

# %%
# get my data
my_data = trading.historic.get_my_data()
for i in my_data:
    print(i)
# Out:
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2015-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2015-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2015-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2016-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2017-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2018-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2019-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2020-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2021-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-10-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-11-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2022-12-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-01-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-02-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-03-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-04-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-05-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-06-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-07-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-08-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-09-01T00:00:00', 'purchaseItemId': 112503}
# {'sport': 'Horse Racing', 'plan': 'Basic Plan', 'forDate': '2023-10-01T00:00:00', 'purchaseItemId': 112503}

# %%
# get collection options (allows filtering)
collection_options = trading.historic.get_collection_options(
    "Horse Racing", "Basic Plan", 1, 3, 2017, 1, 3, 2017
)
print(collection_options)
# Out:
# {'marketTypesCollection': [{'name': 'WIN', 'count': 220}, {'name': '', 'count': 46}, {'name': 'OTHER_PLACE', 'count': 110}, {'name': 'PLACE', 'count': 168}, {'name': 'RACE_WIN_DIST', 'count': 3}, {'name': 'REV_FORECAST', 'count': 15}, {'name': 'EACH_WAY', 'count': 23}, {'name': 'MATCH_BET', 'count': 25}, {'name': 'WITHOUT_FAV', 'count': 2}, {'name': 'FORECAST', 'count': 8}, {'name': 'DAILY_WIN_DIST', 'count': 1}], 'countriesCollection': [{'name': 'US', 'count': 109}, {'name': 'NZ', 'count': 13}, {'name': 'AU', 'count': 151}, {'name': 'IN', 'count': 110}, {'name': 'GB', 'count': 181}, {'name': 'ZA', 'count': 19}, {'name': 'FR', 'count': 17}, {'name': 'DE', 'count': 9}, {'name': 'HK', 'count': 2}, {'name': 'CL', 'count': 10}], 'fileTypeCollection': [{'name': 'M', 'count': 575}, {'name': 'E', 'count': 46}]}

# %%
# get advance basket data size
basket_size = trading.historic.get_data_size(
    "Horse Racing", "Basic Plan", 1, 3, 2017, 1, 3, 2017
)
print(basket_size)
# Out:
# {'totalSizeMB': 2, 'fileCount': 621}

# %%
# get file list
file_list = trading.historic.get_file_list(
    "Horse Racing",
    "Basic Plan",
    from_day=1,
    from_month=3,
    from_year=2017,
    to_day=31,
    to_month=3,
    to_year=2017,
    market_types_collection=["WIN", "PLACE"],
    countries_collection=["GB", "IE"],
    file_type_collection=["M"],
)
print(file_list)
# Out:
# ['/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015028.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015029.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015033.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015034.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015038.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015039.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015043.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015044.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015048.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015049.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015053.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015054.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015761.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015762.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015766.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015767.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015771.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015772.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015776.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015777.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015781.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015782.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015786.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132632/1.130015787.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015916.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015917.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015921.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015922.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015926.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015927.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015931.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015932.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015936.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015937.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015941.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015942.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015946.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132634/1.130015947.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016025.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016026.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016030.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016031.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016035.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016036.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016040.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016041.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016045.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016046.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016050.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132635/1.130016051.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025239.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025240.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025244.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025245.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025249.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025250.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025254.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025255.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/28133761/1.130025259.bz2', '/xds_nfs/hdfs_supreme/BASIC/2017/Mar/2/281337 ...

# %%
# download the files
for file in file_list:
    print(file)
    download = trading.historic.download_file(file_path=file)
    print(download)
# Out:
# /xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015028.bz2
# 1.130015028.bz2
# /xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015029.bz2
# 1.130015029.bz2
# /xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015033.bz2
# 1.130015033.bz2
# /xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015034.bz2
# 1.130015034.bz2
# /xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015038.bz2
# 1.130015038.bz2
# /xds_nfs/hdfs_supreme/BASIC/2017/Mar/1/28132576/1.130015039.bz2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 for file in file_list:
#       3     print(file)
# ----> 4     download = trading.historic.download_file(file_path=file)
#       5     print(download)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/betfairlightweight/endpoints/historic.py:168, in Historic.download_file(self, file_path, store_directory, session)
#     166     local_filename = os.path.join(store_directory, local_filename)
#     167 session = session or self.client.session
# --> 168 r = session.get(
#     169     "%s%s" % (self.url, "DownloadFile"),
#     170     params={"filePath": file_path},
#     171     headers=self.headers,
#     172     stream=True,
#     173     timeout=(self.connect_timeout, self.read_timeout),
#     174 )
#     175 with open(local_filename, "wb") as f:
#     176     for chunk in r.iter_content(chunk_size=1024):
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/algotrading/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
